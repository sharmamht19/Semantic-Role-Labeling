# %%
import os
import numpy as np
import pandas as pd
from conllu import parse
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_recall_fscore_support
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import os
import sys
import codecs
import re
from collections import OrderedDict
import csv

# %%
class Node():

    def __init__(self, text):
        self.text = text
        self.lex = None
        self.type = None
        self.attributes = OrderedDict()
        self.errors = []
        self.name = None
        self.parent = None
        self.parentRelation = None
        self.alignedTo = None
        self.fsList = None
        self.analyzeNode(self.text)

    def analyzeNode(self, text):
        [token, tokenType, fsDict, fsList] = getTokenFeats(
            text.strip().split())
        attributeUpdateStatus = self.updateAttributes(
            token, tokenType, fsDict, fsList)
        if attributeUpdateStatus == 0:
            self.errors.append("Can't update attributes for node")
            self.probSent = True

    def updateAttributes(self, token, tokenType, fsDict, fsList):
        self.fsList = fsList
        self.lex = token
        self.type = tokenType
        for attribute in fsDict.keys():
            self.attributes[attribute] = fsDict[attribute]
        self.assignName()

    def assignName(self):
        if self.attributes.get('name') is not None:
            self.name = self.getAttribute('name')
        else:
            self.errors.append('No name for this token Node')

    def printValue(self):
        return self.lex

    def printSSFValue(self, prefix, allFeat):
        returnValue = [prefix, self.printValue(), self.type]
        if allFeat is False:
            fs = ['<fs']
            for key in self.attributes.keys():
                fs.append(key + "='" + self.getAttribute(key) + "'")
            delim = ' '
            fs[-1] = fs[-1] + '>'

        else:
            fs = self.fsList
            delim = '|'
        return ['\t'.join(x for x in returnValue) + '\t' + delim.join(x for x in fs)]

    def getAttribute(self, key):
        if key in self.attributes:
            return self.attributes[key]
        else:
            return None

    def addAttribute(self, key, value):
        self.attributes[key] = value

    def deleteAttribute(self, key):
        del self.attributes[key]

# %%
class ChunkNode():

    def __init__(self, header):
        self.text = []
        self.header = header
        self.footer = None
        self.nodeList = []
        self.parent = '0'
        self.attributes = OrderedDict()
        self.parentRelation = 'root'
        self.name = None
        self.head = None
        self.isParent = False
        self.errors = []
        self.upper = None
        self.updateDrel()
        self.type = None
        self.fsList = None

    def analyzeChunk(self):
        [chunkType, chunkFeatDict, chunkFSList] = getChunkFeats(self.header)
        self.fsList = chunkFSList
        self.type = chunkType
        self.updateAttributes(chunkFeatDict)
        self.text = '\n'.join([line for line in self.text])

    def updateAttributes(self, fsDict):
        for attribute in fsDict.keys():
            self.attributes[attribute] = fsDict[attribute]
        self.assignName()
        self.updateDrel()

    def assignName(self):
        if 'name' in self.attributes:
            self.name = self.getAttribute('name')
        else:
            self.errors.append('No name for this chunk Node')

    def updateDrel(self):
        if 'drel' in self.attributes:
            drelList = self.getAttribute('drel').split(':')
            if len(drelList) == 2:
                self.parent = drelList[1]
                self.parentRelation = self.getAttribute('drel').split(':')[0]
        elif 'dmrel' in self.attributes:
            drelList = self.getAttribute('dmrel').split(':')
            if len(drelList) == 2:
                self.parent = drelList[1]
                self.parentRelation = self.getAttribute('dmrel').split(':')[0]

    def printValue(self):
        returnString = []
        for node in self.nodeList:
            returnString.append(node.printValue())
        return ' '.join(x for x in returnString)

    def printSSFValue(self, prefix, allFeat):
        returnStringList = []
        returnValue = [prefix, '((', self.type]
        if allFeat is False:
            fs = ['<fs']
            for key in self.attributes.keys():
                fs.append(key + "='" + self.getAttribute(key) + "'")
            delim = ' '
            fs[-1] = fs[-1] + '>'

        else:
            fs = self.fsList
            delim = '|'

        returnStringList.append(
            '\t'.join(x for x in returnValue) + '\t' + delim.join(x for x in fs))
        nodePosn = 0
        for node in self.nodeList:
            nodePosn += 1
            if isinstance(node, ChunkNode):
                returnStringList.extend(
                    node.printSSFValue(prefix + '.' + str(nodePosn), allFeat))
            else:
                returnStringList.extend(
                    node.printSSFValue(prefix + '.' + str(nodePosn), allFeat))
        returnStringList.append('\t' + '))')
        return returnStringList

    def getAttribute(self, key):
        if key in self.attributes:
            return self.attributes[key]
        else:
            return None

    def addAttribute(self, key, value):
        self.attributes[key] = value

    def deleteAttribute(self, key):
        del self.attributes[key]

# %%
class Sentence():

    def __init__(self, sentence, ignoreErrors=True, nesting=True, dummySentence=False):
        self.ignoreErrors = ignoreErrors
        self.nesting = nesting
        self.sentence = None
        self.sentenceID = None
        self.sentenceType = None
        self.length = 0
        self.tree = None
        self.nodeList = []
        self.edges = {}
        self.nodes = {}
        self.tokenNodes = {}
        self.rootNode = None
        self.fileName = None
        self.comment = None
        self.probSent = False
        self.errors = []
        self.text = sentence
        self.dummySentence = dummySentence
        if self.dummySentence is False:

            self.analyzeSentence()

    def analyzeSentence(self, ignoreErrors=False, nesting=True):

        lastContext = self

        for line in self.text.split('\n'):
            stripLine = line.strip()

            if stripLine == "":
                continue
            elif stripLine[0] == "<" and ignoreErrors is False:
                self.errors.append('Encountered a line starting with "<"')
                self.probSent = True
            else:
                splitLine = stripLine.split()
                if len(splitLine) > 0 and splitLine[0] == '))':
                    currentChunkNode.footer = line + '\n'
                    currentChunkNode.analyzeChunk()
                    lastContext = currentChunkNode.upper
                    currentChunkNode = lastContext

                elif len(splitLine) > 1 and splitLine[1] == '((':
                    currentChunkNode = ChunkNode(line + '\n')
                    currentChunkNode.upper = lastContext
                    currentChunkNode.upper.nodeList.append(currentChunkNode)
                    if currentChunkNode.upper.__class__.__name__ != 'Sentence':
                        currentChunkNode.upper.text.append(line)
                    lastContext = currentChunkNode
                else:
                    currentNode = Node(line + '\n')
                    lastContext.nodeList.append(currentNode)
                    currentNode.upper = lastContext

    def addEdge(self, parent, child):
        if parent in self.edges.iterkeys():
            if child not in self.edges[parent]:
                self.edges[parent].append(child)
        else:
            self.edges[parent] = [child]

    def updateAttributes(self):
        populateNodesStatus = self.populateNodes()
        populateEdgesStatus = self.populateEdges()
        self.sentence = self.generateSentence()
        if populateEdgesStatus == 0 or populateNodesStatus == 0:
            return 0
        return 1

    def printSSFValue(self, allFeat):
        returnStringList = []
        returnStringList.append("<Sentence id='" + str(self.sentenceID) + "'>")
        if self.nodeList != []:
            nodeList = self.nodeList
            nodePosn = 0
            for node in nodeList:
                nodePosn += 1
                returnStringList.extend(
                    node.printSSFValue(str(nodePosn), allFeat))
        returnStringList.append('</Sentence>\n')
        return '\n'.join(x for x in returnStringList)

    def populateNodes(self, naming='strict'):
        if naming == 'strict':
            for nodeElement in self.nodeList:
                assert nodeElement.name is not None
                self.nodes[nodeElement.name] = nodeElement
        return 1

    def populateEdges(self):
        for node in self.nodeList:
            nodeName = node.name
            if node.parent == '0' or node == self.rootNode:
                self.rootNode = node
                continue
            elif node.parent not in self.nodes.iterkeys():
                #                self.errors.append('Error : Bad DepRel Parent Name ' + self.fileName + ' : ' + str(self.name))
                return 0
            assert node.parent in self.nodes.iterkeys()
            self.addEdge(node.parent, node.name)
        return 1

    def generateSentence(self):
        sentence = []
        for nodeName in self.nodeList:
            sentence.append(nodeName.printValue())
        return ' '.join(x for x in sentence)


class Document():

    def __init__(self, fileName):
        self.header = None
        self.footer = None
        self.text = None
        self.nodeList = []
        self.fileName = fileName
        self.analyzeDocument()
        self.upper = None

    def analyzeDocument(self):

        inputFD = codecs.open(self.fileName, 'r', encoding='utf8')
#        sentenceList = getSentenceIter(inputFD)
        sentenceList = findSentences(inputFD)
        for sentence in sentenceList:
            tree = Sentence(sentence[1], ignoreErrors=True, nesting=True)
            tree.text = sentence[1]
            tree.sentenceID = int(sentence[0])
            tree.footer = sentence[2]
            tree.header = "<Sentence id='" + sentence[0] + "'"
            tree.upper = self
            self.nodeList.append(tree)
        inputFD.close()


def getAddressNode(address, node, level='ChunkNode'):
    ''' Returns the node referenced in the address string relative to the node in the second argument.
        There are levels for setting the starting address-base. These are "ChunkNode", "Node" , "Sentence" , "Document" , "Relative".
        The hierarchy of levels for interpretation is :
        "Document" -> "Sentence" -> "ChunkNode" -> "Node"
        "Relative" value starts the base address from the node which contains the address. This is also the default option.
    '''

    currentContext = node

    if level != 'Relative':
        while(currentContext.__class__.__name__ != level):
            currentContext = currentContext.upper

    currentContext = currentContext.upper

    stepList = address.split('%')

    for step in stepList:
        if step == '..':
            currentContext = currentContext.upper
        else:
            refNode = [
                iterNode for iterNode in currentContext.nodeList if iterNode.name == step][0]
            currentContext = refNode
    return refNode


def getChunkFeats(line):
    lineList = line.strip().split()
    returnErrors = list()
    chunkType = None
    fsList = []
    if len(lineList) >= 3:
        chunkType = lineList[2]

    returnFeats = OrderedDict()
    multipleFeatRE = r'<fs.*?>'
    featRE = r'(?:\W*)(\S+)=([\'|\"])?([^ \t\n\r\f\v\'\"]*)[\'|\"]?(?:.*)'
    fsList = re.findall(multipleFeatRE, ' '.join(lineList))
    for x in lineList:
        feat = re.findall(featRE, x)
        if feat != []:
            if len(feat) > 1:
                returnErrors.append('Feature with more than one value')
                continue
            returnFeats[feat[0][0]] = feat[0][2]

    return [chunkType, returnFeats, fsList]


def getTokenFeats(lineList):
    tokenType, token = None, None
    returnFeats = OrderedDict()
    fsList = []
    if len(lineList) >= 3:
        tokenType = lineList[2]
    returnErrors = list()
    token = lineList[1]
    multipleFeatRE = r'<fs.*?>'
    featRE = r'(?:\W*)(\S+)=([\'|\"])?([^ \t\n\r\f\v\'\"]*)[\'|\"]?(?:.*)'
    fsList = re.findall(multipleFeatRE, ' '.join(lineList))
    for x in lineList:
        feat = re.findall(featRE, x)
        if feat != []:
            if len(feat) > 1:
                returnErrors.append('Feature with more than one value')
                continue
            returnFeats[feat[0][0]] = feat[0][2]

    return [token, tokenType, returnFeats, fsList]


def getSentenceIter(inpFD):

    sentenceRE = r'''(?P<complete>(?P<header><Sentence id=[\'\"]?(?P<sentenceID>\d+)[\'\"]?>)(?P<text>.*?)(?P<footer></Sentence>))'''
    text = inpFD.read()
    text = text.replace('0xe0', '')
    return re.finditer(sentenceRE, text, re.DOTALL)


def findSentences(inpFD):
    sentenceRE = "<Sentence id='(.*?)'>(.*?)(</Sentence>)"
    text = inpFD.read()
    text = text.replace('0xe0', '')
    return re.findall(sentenceRE, text, re.DOTALL)


def folderWalk(folderPath):
    fileList = []
    for dirPath, dirNames, fileNames in os.walk(folderPath):
        for fileName in fileNames:
            fileList.append(os.path.join(dirPath, fileName))
    return fileList

# %%
inputPath = "Data/"
fileList = folderWalk(inputPath)
newFileList = []
for fileName in fileList:
    # print("hi")
    xFileName = fileName.split('/')[-1]
    if xFileName == 'err.txt' or xFileName.split('.')[-1] in ['comments', 'bak'] or xFileName[:4] == 'task':
        continue
    else:
        newFileList.append(fileName)

# %%
# Define the filename for the CSV file
csv_filename = "sampled_data.csv"
newFileList = newFileList
# Open the CSV file in write mode and create a CSV writer object
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(["Head", "Name", "Post", "Parent", "ParentRelation", "AI", "SRL", "Pred"])

    # Iterate through each file in newFileList
    for fileName in newFileList:
        print(fileName)
        d = Document(fileName)
        for tree in d.nodeList:
            csv_writer.writerow(["----- New Sentence ------"])  # Write separator for each sentence
            for chunkNode in tree.nodeList:
                temp = list(chunkNode.attributes.values())
#                 print(temp)
                key = list(chunkNode.attributes.keys())
                print(key)
                head = ""
                ai = 0
                srl = ""
                pred = ""
                for k in range(len(key)):
                    if key[k] == "head":
                        head = temp[k]

                    elif key[k] == "pbrel":
                        ai = 1
                        srl = temp[k].split(':')[-2]
                        pred = temp[k].split(':')[-1]

                pt = temp[0].split(',')
                if len(pt) > 6:
                    post = pt[6]
                    if post == " " or post == "":
                        post = 0
                else:
                    post = 0

                # Write the extracted data to the CSV file
                csv_writer.writerow([head, chunkNode.name, post, chunkNode.parent, chunkNode.parentRelation, ai, srl, pred])

print("Data saved to", csv_filename)
# Out:
# Data/fullnews_id_2494337_date_1_6_2004.v00.ssf.pb
# ['af', 'head', 'pbrel', 'posn', 'drel', 'name', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'drel', 'name', 'pbrel', 'head', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel']
# ['af', 'posn', 'voicetype', 'name', 'pbrole', 'stype', 'head', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'head', 'pbrel', 'posn', 'drel', 'name', 'vpos']
# ['af', 'posn', 'head', 'name', 'pbrel', 'drel']
# ['af', 'drel', 'posn', 'name', 'pbrel', 'head']
# ['af', 'stype', 'drel', 'pbrole', 'voicetype', 'head', 'name', 'posn']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'drel', 'name', 'posn', 'pbrel', 'head', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'drel', 'name', 'posn', 'head', 'pbrel', 'vpos']
# ['af', 'head', 'pbrel', 'name', 'posn', 'drel']
# ['af', 'head', 'name', 'posn', 'stype', 'drel', 'pbrole', 'voicetype']
# ['af', 'drel', 'posn', 'head', 'pbrel', 'name']
# ['af', 'head', 'pbrel', 'name', 'drel', 'posn', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'pbrel', 'name', 'head', 'posn', 'drel']
# ['af', 'head', 'stype', 'drel', 'pbrole', 'name', 'posn', 'voicetype', 'vpos']
# ['af', 'posn', 'name', 'head']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head', 'pbrel', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'drel', 'name', 'voicetype', 'posn', 'head', 'stype', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'head', 'pbrel', 'name', 'drel', 'posn', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'voicetype', 'pbrole', 'stype']
# ['af', 'drel', 'posn', 'pbrel', 'name', 'head']
# ['af', 'name', 'drel', 'posn', 'head', 'pbrel', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'posn', 'head', 'name', 'voicetype', 'pbrole', 'stype']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn']
# ['af', 'drel', 'name', 'posn', 'head', 'vpos']
# ['pbref', 'head', 'name', 'pbmrel', 'ectype']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'head', 'posn', 'pbrole', 'drel', 'name', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'pbrel', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'name', 'voicetype', 'posn', 'head', 'stype', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'pbrel', 'drel', 'name', 'posn', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head', 'pbrel', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'drel', 'posn', 'head', 'pbrel', 'name']
# ['af', 'name', 'pbrel', 'head', 'posn', 'drel']
# ['af', 'head', 'name', 'posn', 'stype', 'drel', 'voicetype', 'pbrole']
# ['af', 'posn', 'name', 'head']
# ['af', 'name', 'drel', 'posn', 'pbrel', 'head', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel']
# ['af', 'head', 'stype', 'pbrole', 'drel', 'name', 'posn', 'voicetype', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'voicetype', 'posn', 'drel', 'name', 'stype', 'head', 'vpos']
# ['pbmrel', 'name', 'pbref', 'head', 'ectype']
# ['af', 'posn', 'name', 'pbrole', 'drel', 'head', 'vpos']
# ['af', 'posn', 'head', 'pbrel', 'name', 'drel']
# ['af', 'pbrel', 'head', 'name', 'drel', 'posn', 'vpos']
# ['af', 'posn', 'name', 'head', 'pbrole', 'voicetype', 'stype']
# ['af', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'pbrel', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'pbrel', 'posn', 'name', 'drel', 'vpos']
# ['af', 'stype', 'head', 'posn', 'voicetype', 'pbrole', 'name', 'vpos']
# ['af', 'drel', 'pbrel', 'name', 'head', 'posn']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'head', 'name', 'posn', 'drel']
# ['af', 'voicetype', 'pbrole', 'drel', 'stype', 'posn', 'name', 'head']
# ['af', 'head', 'name', 'posn', 'drel']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'drel', 'name', 'posn', 'head', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'name', 'drel', 'posn', 'pbrel', 'head', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'pbrole', 'voicetype', 'drel', 'stype']
# ['af', 'posn', 'name', 'head']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel']
# ['af', 'pbrel', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['ectype', 'head', 'pbmrel', 'name']
# ['af', 'name', 'drel', 'posn', 'head', 'pbrel', 'vpos']
# ['ectype', 'pbmrel', 'name', 'pbref', 'head']
# ['af', 'head', 'posn', 'drel', 'pbrole', 'name', 'vpos']
# ['af', 'pbrel', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'head', 'name', 'posn', 'stype', 'drel', 'pbrole', 'voicetype']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'posn', 'head', 'pbrel', 'name', 'drel']
# ['af', 'drel', 'posn', 'name', 'head']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'drel', 'name', 'head', 'posn']
# ['af', 'posn', 'head', 'name', 'pbrel', 'drel']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'pbrel', 'name', 'head', 'posn', 'drel']
# ['af', 'stype', 'voicetype', 'pbrole', 'head', 'name', 'posn']
# ['af', 'head', 'stype', 'name', 'pbrole', 'voicetype', 'posn', 'vpos']
# ['af', 'drel', 'posn', 'pbrel', 'name', 'head']
# ['af', 'pbrel', 'name', 'head', 'posn', 'drel']
# ['af', 'posn', 'name', 'drel', 'pbrel', 'head', 'vpos']
# ['af', 'posn', 'name', 'head', 'pbrole', 'voicetype', 'drel', 'stype']
# ['af', 'head', 'name', 'posn']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['head', 'name', 'pbmrel', 'ectype']
# ['af', 'pbrel', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'posn', 'head', 'name', 'pbrole', 'drel']
# ['af', 'drel', 'name', 'head', 'posn']
# ['af', 'posn', 'voicetype', 'name', 'drel', 'stype', 'head', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'pbrel', 'posn', 'name', 'drel', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'pbrel', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'posn', 'head', 'name', 'pbrel', 'drel']
# ['af', 'name', 'head', 'posn', 'drel', 'stype', 'voicetype', 'pbrole']
# ['af', 'head', 'name', 'posn']
# ['af', 'drel', 'posn', 'name', 'head']
# ['af', 'voicetype', 'posn', 'drel', 'name', 'stype', 'head', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'head', 'pbrel', 'name', 'posn', 'drel']
# ['af', 'posn', 'name', 'drel', 'pbrel', 'head', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'drel', 'posn', 'name', 'head']
# ['af', 'drel', 'posn', 'name', 'head']
# ['af', 'name', 'drel', 'posn', 'pbrel', 'head', 'vpos']
# ['af', 'head', 'name', 'pbrel', 'posn', 'drel']
# ['af', 'posn', 'head', 'name', 'voicetype', 'pbrole', 'stype', 'drel']
# ['af', 'name', 'pbrel', 'coref', 'head', 'posn', 'drel']
# ['af', 'drel', 'posn', 'name', 'pbrel', 'head']
# ['af', 'drel', 'posn', 'name', 'pbrel', 'head']
# ['af', 'drel', 'pbrole', 'name', 'voicetype', 'posn', 'head', 'stype', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'head', 'name', 'posn', 'stype', 'voicetype']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'head', 'pbrel', 'name', 'drel', 'posn', 'vpos']
# ['ectype', 'head', 'pbref', 'pbmrel', 'name']
# ['af', 'name', 'pbrole', 'drel', 'posn', 'head', 'vpos']
# ['af', 'head', 'pbrel', 'drel', 'name', 'posn', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel']
# ['af', 'head', 'name', 'posn', 'stype', 'drel', 'pbrole', 'voicetype']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'drel', 'name', 'head', 'posn']
# ['dmrel', 'name', 'troot', 'head', 'mtype']
# ['af', 'name', 'head', 'posn']
# ['af', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'drel', 'posn', 'name', 'pbrel', 'head']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'pbrole', 'voicetype', 'drel', 'stype', 'posn', 'name', 'head']
# ['af', 'posn', 'name', 'head']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'head', 'name', 'posn', 'drel']
# ['af', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'drel', 'name', 'pbrel', 'head', 'posn']
# ['af', 'posn', 'name', 'head', 'voicetype', 'pbrole', 'drel', 'stype']
# Data/fullnews_id_2479657_date_27_5_2004.v00.ssf.pb
# ['af', 'name', 'posn', 'head', 'pbrel', 'drel', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel', 'pbrel']
# ['af', 'drel', 'head', 'pbrole', 'posn', 'name', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'name', 'posn', 'stype', 'head', 'voicetype', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'pbrel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'head', 'pbrel', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['dmrel', 'name', 'mtype', 'head', 'pbrel', 'troot']
# ['af', 'pbrole', 'name', 'stype', 'voicetype', 'head', 'posn']
# ['af', 'head', 'name', 'posn']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'drel', 'head', 'vpos']
# ['af', 'name', 'pbrole', 'drel', 'stype', 'head', 'voicetype', 'posn']
# ['af', 'name', 'head', 'drel', 'pbrel', 'posn']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'drel', 'head']
# ['af', 'head', 'drel', 'pbrel', 'name', 'posn', 'vpos']
# ['af', 'voicetype', 'stype', 'head', 'drel', 'name', 'pbrole', 'posn', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'posn', 'name', 'drel', 'voicetype', 'head', 'stype', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'drel', 'head', 'vpos']
# ['af', 'name', 'pbrole', 'stype', 'head', 'voicetype', 'posn']
# ['af', 'posn', 'pbrel', 'drel', 'head', 'name']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'name', 'posn', 'head', 'stype', 'voicetype', 'drel', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'drel', 'head', 'vpos']
# ['af', 'stype', 'head', 'voicetype', 'pbrole', 'name', 'posn']
# ['af', 'posn', 'pbrel', 'drel', 'head', 'name']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'drel', 'stype', 'voicetype', 'head', 'posn', 'name', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'pbrel', 'drel', 'head', 'name', 'posn']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'posn', 'stype', 'head', 'voicetype', 'pbrole', 'name']
# ['af', 'name', 'posn', 'head', 'drel', 'pbrel', 'vpos']
# ['af', 'posn', 'name', 'pbrole', 'stype', 'head', 'voicetype']
# ['af', 'name', 'drel', 'pbrel', 'head', 'posn']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'posn', 'drel', 'stype', 'voicetype', 'head', 'name']
# ['af', 'head', 'drel', 'pbrel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'voicetype', 'head', 'stype', 'pbrole', 'name']
# ['af', 'pbrel', 'drel', 'head', 'name', 'posn']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'stype', 'head', 'voicetype', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'head', 'voicetype', 'stype', 'drel', 'name', 'posn']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'name', 'drel', 'head', 'posn']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'name', 'head', 'pbrel', 'drel']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'head', 'pbrel', 'drel', 'name', 'posn', 'vpos']
# ['af', 'stype', 'voicetype', 'head', 'pbrole', 'posn', 'name', 'vpos']
# ['af', 'head', 'pbrel', 'drel', 'name', 'posn', 'vpos']
# ['af', 'name', 'pbrel', 'drel', 'head', 'posn']
# ['af', 'posn', 'head', 'voicetype', 'stype', 'name', 'pbrole']
# ['af', 'posn', 'name', 'pbrel', 'drel', 'head', 'vpos']
# ['ectype', 'name', 'pbref', 'pbmrel', 'head']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'posn', 'head', 'drel', 'pbrole', 'name']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'name', 'posn', 'stype', 'voicetype', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn']
# ['af', 'name', 'posn', 'head', 'drel', 'pbrel', 'vpos']
# ['pbmrel', 'head', 'name', 'ectype', 'pbref']
# ['af', 'pbrel', 'drel', 'head', 'name', 'posn']
# ['af', 'pbrole', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'posn', 'name', 'voicetype', 'head', 'stype', 'drel']
# ['pbrel', 'troot', 'mtype', 'head', 'name', 'dmrel']
# ['af', 'name', 'drel', 'pbrel', 'head', 'posn']
# ['af', 'stype', 'voicetype', 'head', 'pbrole', 'name', 'posn']
# ['af', 'head', 'drel', 'name', 'posn']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'drel', 'pbrel']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'head', 'drel', 'pbrel', 'name', 'posn']
# ['pbmrel', 'head', 'name', 'ectype', 'pbref']
# ['af', 'pbrel', 'drel', 'head', 'name', 'posn']
# ['af', 'head', 'drel', 'pbrel', 'name', 'posn']
# ['pbref', 'name', 'ectype', 'head', 'pbmrel']
# ['af', 'posn', 'pbrole', 'name', 'head', 'drel', 'pbrel']
# ['af', 'head', 'drel', 'name', 'posn', 'pbrole', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'posn', 'name', 'drel', 'stype', 'head', 'voicetype', 'vpos']
# Data/fullnews_id_2491821_date_1_6_2004.v00.ssf.pb
# ['name', 'pbmrel', 'ectype', 'head']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'pbrel', 'head', 'drel', 'vpos']
# ['head', 'ectype', 'pbmrel', 'pbref', 'name']
# ['af', 'name', 'pbrole', 'posn', 'drel', 'head']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['pbref', 'ectype', 'pbmrel', 'name', 'head']
# ['af', 'name', 'pbrel', 'drel', 'posn', 'head']
# ['af', 'posn', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'pbrel', 'pbrole', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn', 'pbrel', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'pbrel', 'vpos']
# ['af', 'pbrel', 'name', 'head', 'drel', 'posn']
# ['af', 'stype', 'name', 'pbrole', 'posn', 'voicetype', 'head', 'vpos']
# ['af', 'drel', 'head', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['ectype', 'pbref', 'pbmrel', 'name', 'head']
# ['af', 'drel', 'head', 'name', 'posn', 'pbrel', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'pbrel', 'vpos']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'drel', 'head', 'posn', 'name', 'pbrole', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'posn', 'name', 'stype', 'head', 'voicetype', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['head', 'pbref', 'ectype', 'pbmrel', 'name']
# ['af', 'pbrole', 'name', 'head', 'posn', 'drel']
# ['af', 'name', 'pbrel', 'drel', 'posn', 'head']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'voicetype', 'posn', 'name', 'stype', 'vpos']
# ['af', 'drel', 'head', 'pbrel', 'posn', 'name', 'vpos']
# ['head', 'pbref', 'ectype', 'pbmrel', 'name']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'head', 'drel', 'pbrole', 'name', 'pbrel', 'posn', 'vpos']
# ['af', 'name', 'stype', 'pbrole', 'voicetype', 'posn', 'head']
# ['af', 'name', 'pbrel', 'drel', 'posn', 'head']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'posn', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'head', 'drel', 'posn', 'voicetype', 'name', 'stype']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name', 'vpos']
# ['af', 'stype', 'name', 'voicetype', 'pbrole', 'posn', 'head']
# ['af', 'posn', 'drel', 'head', 'name', 'pbrel']
# ['af', 'pbrel', 'name', 'head', 'posn', 'drel']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'name', 'pbrel', 'drel', 'posn', 'head']
# ['af', 'name', 'stype', 'pbrole', 'voicetype', 'drel', 'posn', 'head']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'name', 'stype', 'voicetype', 'posn', 'head']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'pbrel', 'posn', 'name', 'head', 'drel', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name', 'pbrel']
# ['af', 'stype', 'name', 'voicetype', 'pbrole', 'posn', 'drel', 'head']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel', 'vpos']
# ['af', 'pbrole', 'voicetype', 'name', 'stype', 'head', 'posn']
# ['af', 'pbrel', 'name', 'head', 'drel', 'posn']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'posn', 'drel', 'head', 'stype', 'name', 'voicetype', 'pbrole']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'posn', 'drel', 'unaccusative', 'head', 'name', 'pbrole']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'head', 'posn', 'voicetype', 'stype', 'name']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['pbmrel', 'ectype', 'pbref', 'name', 'head']
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'pbrole', 'name', 'head', 'drel', 'posn']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'name', 'stype', 'head', 'voicetype', 'vpos']
# ['name', 'dmrel', 'mtype', 'troot', 'head', 'pbrel']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel']
# ['af', 'posn', 'head', 'stype', 'name', 'voicetype', 'pbrole']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name', 'vpos']
# ['name', 'pbmrel', 'ectype', 'pbref', 'head']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn', 'vpos']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'head', 'drel', 'posn', 'pbrole', 'name', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head', 'vpos']
# ['af', 'pbrel', 'posn', 'name', 'head', 'drel', 'vpos']
# ['af', 'drel', 'head', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head']
# ['af', 'voicetype', 'head', 'drel', 'stype', 'name', 'pbrole', 'posn', 'vpos']
# ['af', 'head', 'posn', 'name']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name', 'vpos']
# ['af', 'pbrel', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel']
# ['af', 'posn', 'name', 'pbrole', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'pbrel', 'head', 'drel', 'vpos']
# ['af', 'head', 'posn', 'drel', 'pbrel', 'name']
# ['af', 'drel', 'head', 'voicetype', 'pbrole', 'name', 'stype', 'posn', 'vpos']
# ['af', 'name', 'pbrel', 'drel', 'posn', 'head']
# ['af', 'drel', 'head', 'name', 'posn', 'pbrel', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn', 'vpos']
# ['af', 'head', 'voicetype', 'posn', 'pbrole', 'name', 'stype', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn', 'pbrel', 'vpos']
# ['head', 'name', 'pbmrel', 'pbref', 'ectype']
# ['af', 'pbrel', 'posn', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'pbrel', 'drel', 'posn', 'head']
# ['af', 'posn', 'drel', 'head', 'name', 'pbrel']
# ['af', 'posn', 'pbrole', 'name', 'head', 'drel', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'voicetype', 'drel', 'head', 'stype', 'name', 'posn', 'vpos']
# ['af', 'name', 'head', 'posn']
# ['af', 'head', 'drel', 'name', 'pbrel', 'posn', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'pbrel', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'pbrel', 'posn', 'name', 'drel', 'head', 'vpos']
# ['name', 'pbref', 'ectype', 'pbmrel', 'head']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name']
# ['af', 'name', 'pbrel', 'pbrole', 'posn', 'drel', 'head']
# ['af', 'name', 'stype', 'posn', 'drel', 'head', 'voicetype', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'drel', 'posn', 'head', 'name', 'stype', 'voicetype']
# Data/fullnews_id_2485531_date_29_5_2004.v00.ssf.pb
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'vpos']
# ['af', 'head', 'posn', 'pbrel', 'name', 'drel']
# ['af', 'drel', 'name', 'pbrel', 'head', 'posn', 'vpos']
# ['af', 'drel', 'pbrel', 'head', 'posn', 'name', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel', 'vpos']
# ['af', 'name', 'posn', 'head', 'pbrel', 'drel', 'vpos']
# ['af', 'pbrole', 'name', 'posn', 'voicetype', 'stype', 'head']
# ['af', 'drel', 'name', 'pbrel', 'head', 'posn', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn']
# ['af', 'name', 'pbrel', 'head', 'posn', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'stype', 'pbrole', 'voicetype', 'vpos']
# ['af', 'pbrel', 'name', 'drel', 'posn', 'head']
# ['af', 'posn', 'head', 'name', 'drel', 'pbrel']
# ['af', 'posn', 'head', 'pbrel', 'name', 'drel']
# ['af', 'drel', 'pbrole', 'name', 'posn', 'stype', 'voicetype', 'head']
# ['af', 'posn', 'head', 'name', 'drel', 'pbrel']
# ['af', 'drel', 'posn', 'head', 'pbrel', 'name', 'vpos']
# ['af', 'drel', 'name', 'pbrel', 'posn', 'head']
# ['af', 'name', 'unaccusative', 'voicetype', 'pbrole', 'drel', 'posn', 'head', 'stype']
# ['af', 'head', 'posn', 'name']
# ['af', 'drel', 'posn', 'head', 'name', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'name', 'drel', 'posn', 'head', 'voicetype', 'stype']
# ['af', 'pbrel', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'drel', 'head', 'posn', 'pbrel', 'name', 'vpos']
# ['af', 'posn', 'stype', 'voicetype', 'head', 'name', 'pbrole']
# ['af', 'drel', 'posn', 'head', 'pbrel', 'name', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'posn', 'head', 'pbrel', 'name', 'drel']
# ['af', 'head', 'posn', 'pbrel', 'drel', 'name']
# ['af', 'pbrel', 'drel', 'voicetype', 'name', 'posn', 'head', 'stype', 'pbrole', 'vpos']
# ['af', 'name', 'drel', 'head', 'posn']
# ['af', 'head', 'posn', 'name', 'drel']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'pbrel', 'name', 'drel', 'head', 'posn']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel', 'vpos']
# ['af', 'name', 'posn', 'head', 'pbrel', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel', 'pbrole', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'name', 'stype', 'voicetype', 'head', 'posn']
# ['af', 'head', 'posn', 'name', 'drel', 'vpos']
# ['af', 'head', 'posn', 'name', 'drel']
# ['af', 'head', 'posn', 'stype', 'name', 'voicetype', 'vpos']
# ['af', 'name', 'drel', 'head', 'posn']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'drel', 'voicetype', 'name', 'stype', 'head', 'posn', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['ectype', 'pbmrel', 'head', 'name']
# ['af', 'drel', 'name', 'posn', 'head', 'pbrel', 'vpos']
# ['af', 'drel', 'name', 'pbrel', 'posn', 'head']
# ['head', 'name', 'pbmrel', 'pbref', 'ectype']
# ['af', 'posn', 'head', 'pbrel', 'name', 'pbrole', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'stype', 'drel', 'voicetype', 'pbrole', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'posn', 'head', 'pbrel', 'drel', 'name']
# ['af', 'drel', 'name', 'posn', 'head', 'vpos']
# ['af', 'posn', 'head', 'pbrel', 'name', 'coref', 'drel', 'vpos']
# ['af', 'pbrole', 'voicetype', 'drel', 'posn', 'head', 'stype', 'name', 'vpos']
# ['name', 'head', 'pbmrel', 'pbref', 'ectype']
# ['af', 'name', 'posn', 'head', 'pbrel', 'drel', 'vpos']
# ['af', 'stype', 'posn', 'head', 'name', 'voicetype', 'pbrole', 'drel', 'vpos']
# Data/fullnews_id_2479533_date_26_5_2004.v00.ssf.pb
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'posn', 'head', 'drel', 'name']
# ['af', 'drel', 'pbrel', 'posn', 'head', 'name']
# ['af', 'posn', 'name', 'head', 'drel', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel', 'vpos']
# ['af', 'drel', 'name', 'pbrel', 'head', 'posn', 'vpos']
# ['af', 'posn', 'head', 'pbrel', 'name', 'drel', 'vpos']
# ['af', 'head', 'posn', 'pbrel', 'drel', 'name']
# ['af', 'voicetype', 'posn', 'pbrole', 'head', 'name', 'stype']
# ['af', 'drel', 'pbrel', 'name', 'head', 'posn', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel', 'vpos']
# ['af', 'pbrole', 'head', 'posn', 'voicetype', 'stype', 'name']
# ['af', 'head', 'posn', 'pbrel', 'drel', 'name']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'name', 'pbrel', 'drel', 'head', 'posn']
# ['pbmrel', 'ectype', 'head', 'name']
# ['af', 'name', 'drel', 'pbrel', 'posn', 'head']
# ['af', 'name', 'drel', 'pbrole', 'head', 'posn']
# ['af', 'drel', 'head', 'posn', 'name']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['mtype', 'head', 'dmrel', 'name', 'pbrel', 'troot']
# ['af', 'drel', 'head', 'pbrole', 'posn', 'voicetype', 'stype', 'name']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'drel', 'name', 'pbrel', 'head', 'posn', 'vpos']
# ['af', 'pbrole', 'head', 'posn', 'voicetype', 'stype', 'name']
# ['af', 'name', 'drel', 'pbrel', 'posn', 'head']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'drel', 'head', 'voicetype', 'name', 'posn', 'stype', 'vpos']
# ['af', 'drel', 'pbrel', 'posn', 'head', 'name']
# ['af', 'head', 'name', 'pbrel', 'posn', 'drel', 'vpos']
# ['af', 'stype', 'name', 'head', 'pbrole', 'posn', 'voicetype']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name']
# ['af', 'name', 'posn', 'head', 'drel', 'pbrel']
# ['pbmrel', 'ectype', 'pbref', 'head', 'name']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name']
# ['af', 'posn', 'head', 'name', 'pbrole', 'drel', 'vpos']
# ['af', 'head', 'posn', 'pbrel', 'drel', 'name']
# ['af', 'stype', 'name', 'pbrole', 'head', 'posn', 'voicetype', 'drel']
# ['pbmrel', 'ectype', 'head', 'name']
# ['af', 'name', 'head', 'posn', 'pbrel', 'drel']
# ['af', 'drel', 'posn', 'pbrole', 'head', 'name']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'pbrel', 'drel']
# ['af', 'posn', 'head', 'pbrel', 'name', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel']
# ['af', 'drel', 'pbrel', 'posn', 'head', 'name']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'stype', 'posn', 'name', 'pbrole', 'voicetype', 'head', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'pbrel', 'vpos']
# ['name', 'head', 'pbref', 'ectype', 'pbmrel']
# ['af', 'drel', 'posn', 'name', 'pbrel', 'head', 'vpos']
# ['af', 'drel', 'pbrel', 'posn', 'head', 'name']
# ['af', 'pbrole', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name']
# ['af', 'name', 'stype', 'posn', 'voicetype', 'head']
# Data/fullnews_id_2477216_date_26_5_2004.v00.ssf.pb
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name']
# ['af', 'drel', 'posn', 'pbrel', 'name', 'head', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'name', 'pbrole', 'posn', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'voicetype', 'name', 'posn', 'stype', 'head']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head']
# ['af', 'head', 'name', 'posn', 'pbrel', 'drel', 'vpos']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'name', 'voicetype', 'posn', 'pbrole', 'head', 'stype']
# ['af', 'drel', 'head', 'name', 'posn', 'pbrel']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'head', 'name', 'drel', 'posn', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'posn', 'drel', 'name', 'voicetype', 'stype', 'vpos']
# ['af', 'head', 'name', 'pbrel', 'posn', 'drel', 'vpos']
# ['af', 'head', 'name', 'pbrel', 'posn', 'drel', 'vpos']
# ['af', 'head', 'name', 'drel', 'posn', 'pbrel', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head']
# ['af', 'head', 'posn', 'pbrole', 'stype', 'voicetype', 'name', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'stype', 'name', 'voicetype', 'drel', 'posn', 'vpos']
# ['af', 'head', 'pbrel', 'posn', 'drel', 'name', 'vpos']
# ['af', 'posn', 'name', 'voicetype', 'head', 'stype', 'pbrole']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'pbrole', 'stype', 'name', 'pbrel', 'drel', 'head', 'voicetype', 'posn']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'drel', 'posn', 'name', 'head', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'head', 'name', 'drel', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'posn', 'drel', 'voicetype', 'name', 'stype', 'vpos']
# ['af', 'head', 'name', 'drel', 'pbrel', 'posn', 'vpos']
# ['af', 'stype', 'head', 'pbrole', 'posn', 'voicetype', 'name']
# ['af', 'pbrel', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn', 'pbrel']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head']
# ['af', 'drel', 'posn', 'name', 'head', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'head', 'posn', 'drel', 'name', 'voicetype', 'stype', 'pbrole', 'vpos']
# ['af', 'head', 'name', 'posn', 'pbrel', 'drel', 'vpos']
# ['af', 'posn', 'voicetype', 'name', 'stype', 'head', 'pbrole']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'name', 'voicetype', 'posn', 'drel', 'head', 'stype']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head', 'vpos']
# ['af', 'pbrel', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'drel', 'posn', 'pbrole', 'stype', 'voicetype', 'name', 'vpos']
# ['af', 'drel', 'pbrel', 'posn', 'name', 'head', 'vpos']
# ['af', 'posn', 'name', 'voicetype', 'head', 'stype', 'pbrole']
# ['af', 'pbrel', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'name', 'drel', 'pbrel', 'posn', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'name', 'drel', 'posn', 'pbrel', 'head', 'vpos']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name']
# ['af', 'head', 'pbrole', 'stype', 'voicetype', 'name', 'drel', 'posn', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name', 'vpos']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head']
# ['af', 'pbrole', 'head', 'stype', 'name', 'voicetype', 'posn']
# ['af', 'head', 'name', 'drel', 'pbrel', 'posn', 'vpos']
# ['af', 'head', 'name', 'drel', 'posn', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'name', 'drel', 'pbrel', 'posn', 'vpos']
# ['af', 'head', 'name', 'pbrel', 'posn', 'drel', 'vpos']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name']
# ['af', 'head', 'name', 'pbrole', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel']
# ['af', 'stype', 'pbrole', 'pbrel', 'name', 'head', 'drel', 'posn', 'voicetype']
# ['af', 'head', 'name', 'posn', 'pbrel', 'drel', 'vpos']
# ['af', 'head', 'stype', 'pbrole', 'posn', 'name', 'voicetype']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'drel', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'name', 'posn', 'drel', 'pbrole', 'head']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'pbrel', 'posn', 'drel', 'name', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head']
# ['name', 'pbmrel', 'head', 'ectype', 'pbref']
# ['af', 'name', 'posn', 'pbrole', 'drel', 'head']
# ['mtype', 'troot', 'name', 'drel', 'pbrel', 'head']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head']
# ['af', 'pbrole', 'stype', 'head', 'voicetype', 'name', 'posn']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'drel', 'posn', 'name', 'head', 'vpos']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'posn', 'pbrel', 'name', 'head', 'drel']
# ['af', 'stype', 'head', 'pbrole', 'drel', 'posn', 'voicetype', 'name']
# ['af', 'pbrel', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'drel', 'pbrel', 'posn', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head']
# ['af', 'posn', 'name', 'head', 'pbrole', 'drel']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'posn', 'pbrel', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name']
# ['af', 'head', 'drel', 'posn', 'pbrel', 'name']
# ['af', 'head', 'pbrole', 'name', 'drel', 'posn', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'stype', 'voicetype', 'name', 'posn', 'vpos']
# Data/fullnews_id_2491783_date_31_5_2004.v00.ssf.pb
# ['af', 'name', 'head', 'drel', 'posn', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name', 'vpos']
# ['af', 'posn', 'drel', 'pbrel', 'head', 'name', 'vpos']
# ['af', 'head', 'pbrel', 'drel', 'posn', 'name']
# ['af', 'pbrole', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'head', 'voicetype', 'posn', 'stype', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'drel', 'head', 'pbrel', 'name', 'posn']
# ['af', 'drel', 'pbrel', 'head', 'name', 'posn']
# ['af', 'pbrole', 'name', 'head', 'stype', 'posn', 'voicetype', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'drel', 'posn', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'name', 'posn', 'drel', 'head']
# ['head', 'pbref', 'pbmrel', 'ectype', 'name']
# ['af', 'posn', 'pbrel', 'drel', 'head', 'name', 'vpos']
# ['af', 'head', 'pbrole', 'name', 'drel', 'posn', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'name', 'stype', 'voicetype', 'posn', 'vpos']
# Data/fullnews_id_2496823_date_2_6_2004.v00.ssf.pb
# ['af', 'drel', 'pbrel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'drel']
# ['ectype', 'name', 'head', 'pbmrel']
# ['af', 'head', 'name', 'drel', 'pbrel']
# ['af', 'head', 'pbrole', 'name', 'drel', 'vpos']
# ['af', 'drel', 'pbrel', 'head', 'name']
# ['af', 'pbrel', 'drel', 'head', 'name', 'vpos']
# ['af', 'name', 'head', 'pbrel', 'drel']
# ['af', 'name', 'head', 'pbrole', 'stype', 'voicetype']
# ['af', 'name', 'head', 'drel', 'pbrel']
# ['af', 'name', 'head', 'drel']
# ['af', 'name', 'head', 'drel']
# ['af', 'name', 'head', 'drel', 'vpos']
# ['af', 'drel', 'name', 'head']
# ['af', 'drel', 'pbrel', 'head', 'name']
# ['af', 'drel', 'pbrel', 'head', 'name', 'vpos']
# ['af', 'head', 'name', 'drel', 'pbrel', 'vpos']
# ['af', 'drel', 'head', 'name']
# ['af', 'drel', 'pbrel', 'head', 'name', 'vpos']
# ['af', 'drel', 'head', 'name']
# ['af', 'pbrel', 'drel', 'head', 'name', 'vpos']
# ['af', 'name', 'head', 'stype', 'voicetype', 'vpos']
# ['pbref', 'head', 'pbmrel', 'name', 'ectype']
# ['af', 'head', 'name', 'drel', 'pbrel', 'vpos']
# ['af', 'pbrole', 'name', 'head', 'drel', 'vpos']
# ['af', 'drel', 'pbrel', 'name', 'head', 'vpos']
# ['af', 'name', 'head', 'drel', 'pbrel']
# ['af', 'pbrole', 'head', 'name', 'voicetype', 'stype']
# ['af', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'drel', 'vpos']
# ['af', 'head', 'name', 'drel', 'vpos']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['ectype', 'head', 'pbref', 'pbmrel', 'name']
# ['af', 'pbrel', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'pbrel', 'drel', 'vpos']
# ['af', 'drel', 'name', 'pbrole', 'head', 'vpos']
# ['af', 'name', 'head', 'pbrel', 'drel']
# ['af', 'pbrel', 'drel', 'head', 'name', 'vpos']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['af', 'drel', 'head', 'name']
# ['af', 'pbrel', 'drel', 'name', 'head']
# ['af', 'name', 'head', 'drel']
# ['af', 'drel', 'pbrel', 'head', 'name', 'vpos']
# ['af', 'voicetype', 'head', 'stype', 'name', 'vpos']
# ['af', 'drel', 'pbrel', 'head', 'coref', 'name']
# ['af', 'drel', 'pbrel', 'head', 'name']
# ['af', 'name', 'head', 'drel', 'pbrel', 'vpos']
# ['af', 'drel', 'voicetype', 'pbrole', 'name', 'stype', 'head', 'vpos']
# ['af', 'drel', 'name', 'head']
# ['af', 'head', 'name', 'drel', 'vpos']
# ['af', 'drel', 'head', 'name', 'vpos']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'drel']
# ['af', 'stype', 'head', 'name', 'voicetype', 'vpos']
# ['af', 'head', 'name', 'pbrel', 'drel', 'vpos']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['af', 'pbrel', 'drel', 'name', 'head']
# ['af', 'name', 'head', 'pbrel', 'drel', 'vpos']
# ['af', 'voicetype', 'head', 'stype', 'pbrole', 'name', 'vpos']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['name', 'head', 'pbref', 'pbmrel', 'ectype']
# ['af', 'pbrel', 'drel', 'head', 'name', 'vpos']
# ['af', 'drel', 'pbrel', 'head', 'name']
# ['af', 'pbrole', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'drel', 'pbrel']
# ['af', 'head', 'name', 'drel', 'pbrel']
# ['ectype', 'pbref', 'head', 'pbmrel', 'name']
# ['af', 'pbrel', 'drel', 'head', 'name', 'vpos']
# ['af', 'name', 'head', 'drel', 'pbrel']
# ['af', 'pbrole', 'head', 'name', 'pbrel', 'drel']
# ['af', 'pbrole', 'name', 'stype', 'head', 'voicetype', 'vpos']
# ['af', 'head', 'name', 'drel', 'vpos']
# ['ectype', 'name', 'pbref', 'head', 'pbmrel']
# ['af', 'name', 'head', 'drel', 'pbrel']
# ['af', 'drel', 'name', 'pbrole', 'head', 'vpos']
# ['af', 'drel', 'name', 'head']
# ['af', 'name', 'head', 'drel', 'pbrel', 'vpos']
# ['af', 'drel', 'head', 'name']
# ['af', 'drel', 'head', 'name', 'vpos']
# ['af', 'name', 'head', 'drel']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['af', 'name', 'head', 'drel']
# ['af', 'voicetype', 'head', 'stype', 'name', 'vpos']
# ['af', 'head', 'name', 'drel', 'pbrel', 'vpos']
# ['af', 'drel', 'name', 'head']
# ['af', 'name', 'head', 'drel', 'pbrel']
# ['af', 'head', 'name', 'drel', 'vpos']
# ['af', 'head', 'name', 'drel', 'pbrel']
# ['af', 'head', 'name', 'drel', 'pbrel', 'vpos']
# ['af', 'drel', 'pbrel', 'head', 'name', 'vpos']
# ['af', 'name', 'stype', 'head', 'voicetype', 'vpos']
# ['af', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'drel']
# ['af', 'drel', 'pbrel', 'head', 'name']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'drel', 'pbrel', 'vpos']
# ['af', 'pbrel', 'drel', 'name', 'head', 'vpos']
# ['af', 'drel', 'pbrel', 'head', 'name']
# ['af', 'voicetype', 'name', 'pbrole', 'head', 'stype', 'vpos']
# ['af', 'drel', 'head', 'name', 'vpos']
# ['af', 'name', 'head', 'pbrel', 'drel']
# ['af', 'name', 'head', 'pbrel', 'drel', 'vpos']
# ['af', 'head', 'name', 'pbrole', 'stype', 'drel', 'voicetype']
# ['af', 'name', 'head']
# ['af', 'drel', 'name', 'head']
# ['af', 'drel', 'pbrel', 'head', 'name']
# ['af', 'head', 'name', 'drel', 'pbrel', 'vpos']
# ['af', 'pbrole', 'head', 'name', 'voicetype', 'stype', 'drel']
# ['dmrel', 'mtype', 'pbrel', 'name', 'head']
# ['af', 'name', 'head', 'mtype', 'pbrel', 'troot', 'drel']
# ['af', 'pbrole', 'name', 'head', 'voicetype', 'stype']
# ['af', 'drel', 'head', 'name']
# ['af', 'name', 'head', 'drel', 'vpos']
# ['af', 'drel', 'head', 'name', 'vpos']
# ['af', 'head', 'name', 'drel', 'vpos']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'name', 'drel']
# ['af', 'head', 'name', 'drel', 'vpos']
# ['af', 'head', 'name', 'drel']
# ['af', 'drel', 'head', 'name']
# ['af', 'drel', 'voicetype', 'head', 'stype', 'name', 'vpos']
# ['af', 'head', 'name']
# ['af', 'name', 'head', 'drel', 'pbrel', 'vpos']
# ['af', 'head', 'name', 'drel', 'vpos']
# ['af', 'drel', 'head', 'name']
# ['af', 'drel', 'name', 'head', 'vpos']
# ['af', 'pbrel', 'drel', 'name', 'head']
# ['af', 'drel', 'voicetype', 'name', 'pbrole', 'head', 'stype', 'vpos']
# Data/fullnews_id_2491812_date_1_6_2004.v00.ssf.pb
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name']
# ['af', 'head', 'posn', 'name', 'drel']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['head', 'pbmrel', 'ectype', 'name']
# ['af', 'name', 'pbrel', 'drel', 'head', 'posn', 'vpos']
# ['af', 'name', 'posn', 'pbrole', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name']
# ['af', 'head', 'posn', 'stype', 'voicetype', 'name', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'coref', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel']
# ['af', 'voicetype', 'drel', 'stype', 'posn', 'head', 'name']
# ['af', 'drel', 'name', 'head', 'posn']
# ['name', 'ectype', 'pbmrel', 'head', 'pbref']
# ['af', 'head', 'posn', 'pbrel', 'name', 'drel']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'posn', 'pbrole', 'name']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'head', 'posn', 'name', 'drel']
# ['af', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'drel', 'pbrel', 'posn', 'head', 'name']
# ['af', 'head', 'posn', 'name', 'drel']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'drel', 'name', 'posn', 'head']
# ['af', 'name', 'posn', 'stype', 'voicetype', 'head', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel']
# ['af', 'pbrel', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name', 'vpos']
# ['af', 'name', 'posn', 'pbrel', 'head', 'drel']
# ['af', 'drel', 'name', 'pbrel', 'posn', 'head']
# ['af', 'head', 'posn', 'voicetype', 'stype', 'pbrole', 'unaccusative', 'name', 'vpos']
# ['ectype', 'name', 'head', 'pbmrel']
# ['af', 'posn', 'head', 'drel', 'pbrel', 'name', 'vpos']
# ...
# ['af', 'pbrole', 'posn', 'name', 'drel', 'head', 'voicetype', 'stype', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'head', 'drel', 'name', 'posn']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'pbrel', 'name', 'posn', 'vpos']
# ['af', 'drel', 'head', 'pbrel', 'posn', 'name', 'vpos']
# ['af', 'pbrel', 'posn', 'name', 'head', 'drel', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'head', 'drel', 'pbrel', 'name', 'posn']
# ['af', 'drel', 'stype', 'pbrole', 'head', 'voicetype', 'name', 'posn']
# ['af', 'drel', 'head', 'pbrel', 'name', 'posn']
# ['af', 'stype', 'pbrole', 'head', 'voicetype', 'posn', 'name']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'head', 'drel', 'name', 'posn']
# ['af', 'head', 'drel', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name']
# ['af', 'head', 'drel', 'stype', 'voicetype', 'posn', 'name', 'vpos']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name']
# ['af', 'pbrel', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'name', 'posn', 'head', 'drel', 'pbrel']
# ['af', 'name', 'posn', 'pbrole', 'stype', 'head', 'voicetype']
# ['af', 'pbrel', 'head', 'drel', 'posn', 'name']
# ['af', 'drel', 'head', 'pbrel', 'name', 'posn', 'vpos']
# ['af', 'name', 'posn', 'pbrole', 'stype', 'voicetype', 'head']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'posn', 'name', 'pbrel', 'head', 'drel']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'head', 'drel', 'pbrel', 'name', 'posn']
# ['af', 'posn', 'name', 'pbrole', 'stype', 'drel', 'voicetype', 'head']
# ['af', 'name', 'posn', 'head', 'drel']
# ['af', 'name', 'posn', 'drel', 'head', 'vpos']
# ['af', 'posn', 'name', 'pbrel', 'drel', 'head']
# ['ectype', 'name', 'head', 'pbmrel']
# ['af', 'head', 'voicetype', 'drel', 'stype', 'pbrole', 'posn', 'name']
# ['ectype', 'pbref', 'name', 'head', 'pbmrel']
# ['af', 'pbrel', 'drel', 'head', 'posn', 'name']
# ['af', 'pbrole', 'stype', 'drel', 'head', 'voicetype', 'posn', 'name']
# ['name', 'head', 'pbmrel', 'ectype', 'pbref']
# ['af', 'drel', 'head', 'posn', 'name', 'pbrel', 'vpos']
# ['af', 'head', 'drel', 'voicetype', 'stype', 'pbrole', 'posn', 'name', 'vpos']
# ['af', 'drel', 'head', 'posn', 'name']
# ['af', 'pbrel', 'head', 'drel', 'posn', 'name']
# ['af', 'head', 'drel', 'name', 'posn', 'pbrel', 'vpos']
# ['af', 'pbrole', 'name', 'posn', 'drel', 'head', 'stype', 'voicetype', 'vpos']
# ['af', 'pbrel', 'head', 'drel', 'posn', 'name']
# ['af', 'name', 'posn', 'pbrel', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'pbrole', 'stype', 'voicetype', 'head']
# ['af', 'pbrel', 'head', 'drel', 'posn', 'name']
# ['af', 'drel', 'head', 'name', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'name', 'stype', 'voicetype', 'head', 'drel', 'vpos']
# Data/fullnews_id_2479633_date_26_5_2004.v00.ssf.pb
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['af', 'posn', 'head', 'stype', 'name', 'pbrole', 'voicetype', 'vpos']
# ['af', 'pbrel', 'drel', 'head', 'name', 'posn']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'head', 'name', 'drel', 'posn']
# ['af', 'drel', 'posn', 'head', 'stype', 'voicetype', 'name', 'vpos']
# ['af', 'pbrel', 'name', 'drel', 'posn', 'head', 'vpos']
# ['ectype', 'name', 'head', 'pbref', 'pbmrel']
# ['af', 'name', 'pbrole', 'posn', 'head', 'drel', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name', 'pbrel']
# ['af', 'pbrel', 'drel', 'head', 'name', 'posn']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'name', 'voicetype', 'posn', 'stype', 'head', 'drel', 'vpos']
# ['af', 'posn', 'head', 'name']
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['af', 'pbrel', 'name', 'head', 'drel', 'posn']
# ['af', 'posn', 'stype', 'pbrole', 'drel', 'name', 'head', 'voicetype']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'name', 'posn', 'head', 'drel', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'pbrel', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'stype', 'pbrole', 'posn', 'voicetype', 'name', 'head']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'posn', 'head', 'name', 'drel', 'pbrel']
# ['af', 'drel', 'name', 'head', 'posn']
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['af', 'drel', 'head', 'name', 'pbrel', 'posn']
# ['af', 'drel', 'posn', 'head', 'stype', 'voicetype', 'name', 'pbrole', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel', 'pbrel']
# ['af', 'posn', 'pbrel', 'head', 'name', 'drel']
# ['af', 'pbrel', 'name', 'pbrole', 'drel', 'posn', 'head', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel', 'pbrel']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'voicetype', 'name', 'pbrole', 'posn', 'head', 'stype', 'vpos']
# ['af', 'posn', 'pbrel', 'drel', 'head', 'name']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'posn', 'head', 'drel', 'name', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'voicetype', 'drel', 'name', 'head', 'stype', 'posn']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'voicetype', 'head', 'name', 'drel', 'stype', 'posn']
# ['af', 'head', 'name', 'posn']
# ['af', 'pbrel', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'drel', 'posn', 'head', 'name', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'head', 'name', 'drel', 'posn']
# ['ectype', 'name', 'head', 'pbref', 'pbmrel']
# ['af', 'pbrel', 'name', 'drel', 'posn', 'head', 'vpos']
# ['ectype', 'name', 'head', 'pbref', 'pbmrel']
# ['af', 'posn', 'head', 'name', 'drel', 'pbrel']
# ['af', 'pbrel', 'name', 'pbrole', 'drel', 'posn', 'head', 'vpos']
# ['af', 'drel', 'head', 'posn', 'pbrole', 'name', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel']
# ['af', 'posn', 'stype', 'name', 'head', 'drel', 'voicetype']
# ['af', 'pbrel', 'drel', 'head', 'name', 'posn']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrel', 'vpos']
# ['af', 'name', 'pbrel', 'head', 'posn', 'drel', 'vpos']
# ['af', 'pbrel', 'head', 'name', 'drel', 'posn']
# ['af', 'voicetype', 'name', 'pbrole', 'posn', 'stype', 'head', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrel', 'vpos']
# ['af', 'pbrel', 'name', 'head', 'drel', 'posn']
# ['af', 'head', 'posn', 'drel', 'name', 'pbrel', 'vpos']
# ['pbmrel', 'pbref', 'head', 'name', 'ectype']
# ['af', 'posn', 'name', 'head', 'drel', 'pbrel']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrole', 'pbrel', 'vpos']
# ['af', 'voicetype', 'name', 'pbrole', 'posn', 'stype', 'head', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'name', 'head', 'drel', 'pbrel']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrole', 'vpos']
# ['af', 'drel', 'head', 'posn', 'pbrel', 'name', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name', 'vpos']
# ['pbref', 'pbmrel', 'name', 'head', 'ectype']
# ['af', 'drel', 'posn', 'head', 'pbrel', 'name', 'vpos']
# ['af', 'drel', 'head', 'posn', 'pbrole', 'name', 'vpos']
# ['af', 'name', 'head', 'drel', 'posn']
# ['af', 'posn', 'name', 'head', 'drel']
# ['af', 'voicetype', 'name', 'head', 'stype', 'posn']
# ['af', 'posn', 'head', 'drel', 'name', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'drel', 'posn', 'head', 'pbrel', 'name', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrel', 'vpos']
# ['ectype', 'pbref', 'pbmrel', 'name', 'head']
# ['af', 'pbrole', 'name', 'unaccusative', 'head', 'posn', 'drel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrel', 'vpos']
# ['af', 'name', 'head', 'drel', 'pbrel', 'posn']
# ['af', 'posn', 'head', 'name', 'drel', 'pbrel']
# ['af', 'name', 'pbrole', 'voicetype', 'posn', 'head', 'stype', 'vpos']
# ['af', 'name', 'pbrel', 'posn', 'head', 'drel', 'vpos']
# ['af', 'pbrel', 'name', 'drel', 'posn', 'head', 'vpos']
# ['af', 'pbrel', 'head', 'name', 'drel', 'posn']
# ['af', 'name', 'pbrole', 'voicetype', 'posn', 'stype', 'head', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn']
# ['af', 'posn', 'head', 'drel', 'name', 'vpos']
# ['af', 'name', 'head', 'posn', 'drel', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'drel', 'head', 'posn', 'name', 'vpos']
# ['af', 'posn', 'drel', 'head', 'name']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'drel', 'head', 'name', 'posn']
# ['af', 'drel', 'stype', 'head', 'posn', 'voicetype', 'name', 'vpos']
# Data/ssf/fullnews_id_2474841_date_25_5_2004.v00.ssf.pb
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['name', 'pbref', 'pbmrel', 'head', 'ectype']
# ['af', 'head', 'pbrel', 'drel', 'posn', 'name']
# ['af', 'posn', 'name', 'drel', 'head', 'pbrole', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel', 'pbrel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrel', 'vpos']
# ['af', 'stype', 'voicetype', 'posn', 'name', 'head', 'pbrole', 'vpos']
# ['af', 'name', 'drel', 'posn', 'pbrel', 'head']
# ['af', 'pbrel', 'head', 'name', 'drel', 'posn']
# ['af', 'head', 'pbrel', 'name', 'posn', 'drel']
# ['af', 'posn', 'pbrel', 'head', 'drel', 'name', 'vpos']
# ['af', 'pbrel', 'head', 'name', 'drel', 'posn']
# ['af', 'pbrole', 'head', 'voicetype', 'name', 'posn', 'drel', 'stype']
# ['pbrel', 'mtype', 'troot', 'drel', 'head', 'name']
# ['af', 'drel', 'posn', 'name', 'head', 'pbrel']
# ['af', 'head', 'pbrole', 'stype', 'posn', 'name', 'voicetype']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'pbrel', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'pbrel', 'head', 'drel', 'name', 'vpos']
# ['af', 'pbrel', 'head', 'name', 'drel', 'posn']
# ['af', 'drel', 'name', 'head', 'pbrole', 'posn', 'stype', 'voicetype', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'drel', 'head', 'vpos']
# ['af', 'pbrel', 'head', 'posn', 'drel', 'name']
# ['af', 'posn', 'drel', 'name', 'head', 'pbrel']
# ['af', 'posn', 'pbrel', 'head', 'name', 'drel', 'vpos']
# ['ectype', 'head', 'pbref', 'pbmrel', 'name']
# ['af', 'name', 'drel', 'posn', 'pbrole', 'head']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'posn', 'head', 'name', 'drel', 'vpos']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'pbrole', 'head', 'name', 'voicetype', 'posn', 'stype']
# ['name', 'pbmrel', 'pbref', 'head', 'ectype']
# ['af', 'pbrel', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'drel', 'posn', 'name', 'head', 'pbrel']
# ['af', 'pbrole', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'posn', 'voicetype', 'stype', 'name', 'head', 'pbrole', 'vpos']
# ['af', 'name', 'posn', 'drel', 'pbrel', 'head']
# ['af', 'pbrel', 'head', 'posn', 'drel', 'name']
# ['af', 'pbrel', 'head', 'name', 'drel', 'posn']
# ['af', 'posn', 'voicetype', 'stype', 'head', 'drel', 'name', 'pbrole', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'posn', 'head', 'name', 'drel', 'vpos']
# ['af', 'head', 'name', 'drel', 'posn']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'head', 'drel', 'posn', 'stype', 'name', 'voicetype']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['pbref', 'pbmrel', 'name', 'ectype', 'head']
# ['af', 'posn', 'name', 'drel', 'head', 'pbrel', 'vpos']
# ['af', 'posn', 'pbrel', 'name', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head', 'pbrel']
# ['af', 'name', 'drel', 'head', 'pbrole', 'posn', 'vpos']
# ['af', 'name', 'drel', 'posn', 'pbrel', 'head']
# ['af', 'drel', 'name', 'head', 'pbrole', 'stype', 'voicetype', 'posn', 'vpos']
# ['af', 'head', 'posn', 'name']
# ['af', 'drel', 'posn', 'name', 'head', 'pbrel']
# ['af', 'posn', 'drel', 'name', 'head', 'pbrel', 'vpos']
# ['head', 'ectype', 'name', 'pbref', 'pbmrel']
# ['af', 'drel', 'name', 'head', 'pbrole', 'posn', 'vpos']
# ['af', 'pbrel', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'head', 'pbrole', 'posn', 'stype', 'drel', 'voicetype', 'name']
# ['af', 'posn', 'pbrel', 'head', 'drel', 'name', 'vpos']
# ['af', 'name', 'head', 'pbrole', 'posn', 'voicetype', 'stype', 'vpos']
# ['af', 'drel', 'posn', 'name', 'pbrel', 'head']
# ['af', 'name', 'drel', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'head', 'pbrel', 'name', 'posn', 'drel']
# ['af', 'pbrel', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'drel', 'name', 'head', 'pbrole', 'posn', 'voicetype', 'stype', 'vpos']
# ['name', 'pbmrel', 'pbref', 'head', 'ectype']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'pbrole', 'head']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name', 'vpos']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'name', 'drel', 'posn', 'head']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'pbrel', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'voicetype', 'name', 'posn', 'stype', 'pbrole', 'head']
# ['af', 'drel', 'posn', 'name', 'head', 'pbrel']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'head', 'name', 'drel', 'posn', 'vpos']
# ['af', 'head', 'name', 'drel', 'pbrel', 'posn', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'pbrel', 'vpos']
# ['af', 'posn', 'head', 'drel', 'name', 'pbrole', 'vpos']
# ['af', 'head', 'drel', 'posn', 'name']
# ['af', 'posn', 'drel', 'stype', 'voicetype', 'name', 'head']
# ['af', 'head', 'drel', 'name', 'posn', 'vpos']
# ['af', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'pbrel', 'head', 'drel', 'name', 'vpos']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'stype', 'posn', 'name', 'voicetype', 'head', 'pbrole']
# ['af', 'name', 'drel', 'posn', 'head', 'pbrel']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'head', 'stype', 'posn', 'drel', 'voicetype', 'name']
# ['troot', 'mtype', 'pbrel', 'name', 'drel', 'head']
# ['af', 'name', 'drel', 'posn', 'pbrel', 'head']
# ['af', 'stype', 'posn', 'voicetype', 'name', 'head', 'pbrole']
# ['af', 'head', 'name', 'posn', 'drel']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'stype', 'voicetype', 'head', 'drel', 'name', 'vpos']
# ['af', 'head', 'name', 'drel', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'posn', 'head', 'name', 'drel', 'vpos']
# ['af', 'head', 'name', 'posn', 'drel']
# ['af', 'drel', 'posn', 'name', 'head']
# ['af', 'head', 'drel', 'name', 'posn', 'voicetype', 'stype', 'vpos']
# ['af', 'name', 'posn', 'head']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'name', 'drel', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'pbrel', 'head', 'name', 'posn', 'drel']
# ['af', 'stype', 'voicetype', 'posn', 'pbrole', 'drel', 'name', 'head', 'vpos']
# ['pbrel', 'troot', 'mtype', 'head', 'drel', 'name']
# ['af', 'name', 'posn', 'drel', 'head', 'pbrel']
# ['af', 'head', 'pbrole', 'posn', 'stype', 'name', 'voicetype']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'name', 'drel', 'head', 'posn', 'vpos']
# ['af', 'posn', 'name', 'drel', 'head', 'vpos']
# ['af', 'posn', 'drel', 'name', 'head']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'pbrel', 'head', 'drel', 'name', 'posn', 'vpos']
# ['name', 'pbref', 'pbmrel', 'head', 'ectype']
# ['af', 'drel', 'name', 'head', 'pbrel', 'posn', 'vpos']
# ['af', 'name', 'drel', 'head', 'pbrole', 'posn', 'vpos']
# ['af', 'head', 'posn', 'drel', 'name']
# ['af', 'posn', 'drel', 'name', 'head', 'vpos']
# ['af', 'head', 'drel', 'name', 'pbrel', 'posn', 'vpos']
# ['af', 'drel', 'name', 'head', 'posn', 'vpos']
# ['af', 'name', 'posn', 'drel', 'head']
# ['af', 'stype', 'voicetype', 'posn', 'drel', 'name', 'head', 'vpos']
# Data saved to sampled_data.csv

# %%
# Define the filenames for the input and output CSV files
input_csv_filename = "sampled_data.csv"
output_csv_filename = "output_dataset.csv"

# Open the input CSV file in read mode
with open(input_csv_filename, 'r', newline='', encoding='utf-8') as input_file:
    csv_reader = csv.reader(input_file)
    
    # Open the output CSV file in write mode
    with open(output_csv_filename, 'w', newline='', encoding='utf-8') as output_file:
        csv_writer = csv.writer(output_file)
        
        # Write the header row to the output CSV file
        csv_writer.writerow(["Sentence", "SRLs"])
        
        # Skip the header row in the input CSV file
        next(csv_reader)
        
        # Initialize variables to store the current sentence and its SRLs
        current_sentence = []
        current_srls = []

        # Iterate through each row in the input CSV file
        for row in csv_reader:
            # Check if the row represents the start of a new sentence
            if row[0] == "----- New Sentence ------":
                # If it is not the first sentence, write the previous sentence and its SRLs to the output CSV file
                if current_sentence:
                    csv_writer.writerow([' '.join(current_sentence), ' '.join(current_srls)])
                
                # Assign the current row as the start of a new sentence
                current_sentence = []  # Store the sentence
                current_srls = []  # Reset the SRLs for the new sentence
            else:
                # If it's not the start of a new sentence
                # Append the token from the current row to the current sentence
                current_sentence.append(row[0])

                # Check if the 6th column value is "1"
                if row[5] == "1":
                    # If it is, append the SRL from the 7th column to the current SRLs
                    current_srls.append(row[6])
                else:
                    # If not, append "NO_SRL" to the current SRLs
                    current_srls.append("NO_SRL")
        
        # Write the last sentence and its SRLs after processing all rows
        if current_sentence:
            csv_writer.writerow([' '.join(current_sentence), ' '.join(current_srls)])

print("Output dataset has been saved to:", output_csv_filename)
# Out:
# Output dataset has been saved to: output_dataset.csv

# %%
# Define the filenames for the input and output CSV files
input_csv_filename = "sampled_data.csv"

# Define an empty set to store unique ParentRelation values
parent_relation_set = set()

# Open the input CSV file in read mode
with open(input_csv_filename, 'r', newline='', encoding='utf-8') as input_file:
    csv_reader = csv.reader(input_file)
    
    # Skip the header row in the input CSV file
    next(csv_reader)
    
    # Iterate through each row in the input CSV file
    for row in csv_reader:
        if row[0] == "----- New Sentence ------":
            continue
        # Get the ParentRelation value from the row
        parent_relation = row[4]  # Assuming ParentRelation is in the 4th column
        
        # Add the ParentRelation value to the set
        parent_relation_set.add(parent_relation)

# Print the set of unique ParentRelation values
print("Unique ParentRelation values:", parent_relation_set)
# Out:
# Unique ParentRelation values: {'root', 'k1u', 'k1g', 'pof-idiom', 'rd', 'mod', 'ccof', 'rh', 'k2u', 'ras-k7p', 'k2g', 'enm', 'k7', 'rs', 'r6v', 'pk1', 'r6', 'k7p', 'ras-k7', 'k3', 'ras-k1', 'fragof', 'nmod__k1inv', 'k2', 'k7ts', 'ras-neg-k1', 'nmod__relc', 'pof', 'sent-adv', 'k4u', 'k5prk', 'r6-k1', 'nmod__k2inv', 'nmod__pofinv', 'rbmod__relc', 'k1', 'k5', 'jjmod', 'k7t', 'jk1', 'k7pu', 'adv', 'rsp', 'rt', 'r6-k2', 'nmod', 'ras-k2', 'k2p', 'mk1', 'k2s', 'ras-r6', 'vmod', 'ras', 'k4a', 'vmod__adv', 'k4', 'k1s', 'rbmod'}

# %%
# Define the filenames for the input and output CSV files
input_csv_filename = "sampled_data.csv"
output_csv_filename = "output_drel_dataset.csv"

# Open the input CSV file in read mode
with open(input_csv_filename, 'r', newline='', encoding='utf-8') as input_file:
    csv_reader = csv.reader(input_file)
    
    # Open the output CSV file in write mode
    with open(output_csv_filename, 'w', newline='', encoding='utf-8') as output_file:
        csv_writer = csv.writer(output_file)
        
        # Write the header row to the output CSV file
        csv_writer.writerow(["Sentence", "Dependency", "SRLs"])
        
        # Skip the header row in the input CSV file
        next(csv_reader)
        
        # Initialize variables to store the current sentence and its SRLs and Dependency
        current_sentence = []
        current_srls = []
        current_dependency = []

        # Iterate through each row in the input CSV file
        for row in csv_reader:
            # Check if the row represents the start of a new sentence
            if row[0] == "----- New Sentence ------":
                # If it is not the first sentence, write the previous sentence and its SRLs to the output CSV file
                if current_sentence:
                    csv_writer.writerow([' '.join(current_sentence), ' '.join(current_dependency), ' '.join(current_srls)])
                
                # Assign the current row as the start of a new sentence
                current_sentence = []  # Store the sentence
                current_srls = []  # Reset the SRLs for the new sentence
                current_dependency = []  # Reset the Dependency for the new sentence
            else:
                # If it's not the start of a new sentence
                # Append the token from the current row to the current sentence
                current_sentence.append(row[0])

                # Check if the 6th column value is "1"
                if row[5] == "1":
                    # If it is, append the SRL from the 7th column to the current SRLs
                    current_srls.append(row[6])
                else:
                    # If not, append "NO_SRL" to the current SRLs
                    current_srls.append("NO_SRL")
                
                # Append the Dependency from the 4th column to the current Dependency
                current_dependency.append(row[4])

        # Write the last sentence, its SRLs, and Dependency after processing all rows
        if current_sentence:
            csv_writer.writerow([' '.join(current_sentence), ' '.join(current_dependency), ' '.join(current_srls)])

print("Output dataset has been saved to:", output_csv_filename)
# Out:
# Output dataset has been saved to: output_drel_dataset.csv

# %%
def print_token_counts(filename):
    # Open the CSV file in read mode
    with open(filename, 'r', newline='', encoding='utf-8') as csvfile:
        csv_reader = csv.reader(csvfile)

        # Get the header row
        header = next(csv_reader)

        # Iterate through each row in the CSV file
        for row_number, row in enumerate(csv_reader, start=1):
            # Split tokens in the first column to count tokens
            first_column_tokens = row[0].split()
            first_column_token_count = len(first_column_tokens)

            # Iterate through each column except the first one
            for col_number, token in enumerate(row[1:], start=2):
                # Count the number of tokens in the current column
                column_token_count = len(token.split())

                # Check if the token count for the current column is different from the first column
                if column_token_count != first_column_token_count:
                    print(f"For row {row_number}, column {col_number}: "
                          f"Different token count ({column_token_count} tokens) "
                          f"than the first column ({first_column_token_count} tokens)")

# %%
# Test the function with the provided CSV file
filename = "output_drel_dataset.csv"
print_token_counts(filename)
filename = "output_dataset.csv"
print_token_counts(filename)
# Out:
# For row 446, column 2: Different token count (20 tokens) than the first column (19 tokens)
# For row 446, column 3: Different token count (20 tokens) than the first column (19 tokens)
# For row 516, column 2: Different token count (22 tokens) than the first column (21 tokens)
# For row 516, column 3: Different token count (22 tokens) than the first column (21 tokens)
# For row 446, column 2: Different token count (20 tokens) than the first column (19 tokens)
# For row 516, column 2: Different token count (22 tokens) than the first column (21 tokens)

# %%
def remove_rows_with_mismatch(filename):
    # Open the CSV file in read mode and create a list to store rows to remove
    rows_to_remove = []
    rows = []  # List to store non-header rows

    # Read the CSV file and identify rows with mismatched token counts
    with open(filename, 'r', newline='', encoding='utf-8') as csvfile:
        csv_reader = csv.reader(csvfile)
        
        # Get the header row
        header = next(csv_reader)
        
        # Iterate through each row in the CSV file
        for row_number, row in enumerate(csv_reader, start=1):
            # Split tokens in the first column to count tokens
            first_column_tokens = row[0].split()
            first_column_token_count = len(first_column_tokens)

            # Iterate through each column except the first one
            for col_number, token in enumerate(row[1:], start=2):
                # Count the number of tokens in the current column
                column_token_count = len(token.split())

                # Check if the token count for the current column is different from the first column
                if column_token_count != first_column_token_count:
                    # Add the row number to the list of rows to remove
                    rows_to_remove.append(row_number)
                    break  # Break the loop as we only need to check one column
            else:
                # If no mismatch is found, add the row to the list of non-header rows
                rows.append(row)

    # Remove rows with mismatched token counts from the list of rows
    for row_number in reversed(rows_to_remove):  # Iterate in reverse to avoid index issues
        del rows[row_number - 1]  # Adjust row number to account for header

    # Write the filtered rows back to the original CSV file
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)  # Write the header row
        csv_writer.writerows(rows)   # Write the filtered rows

# %%
# Test the function with the provided CSV file
filename = "output_drel_dataset.csv"
remove_rows_with_mismatch(filename)
# Test the function with the provided CSV file
filename = "output_dataset.csv"
remove_rows_with_mismatch(filename)

# %%
# Test the function with the provided CSV file
filename = "output_drel_dataset.csv"
print_token_counts(filename)
filename = "output_dataset.csv"
print_token_counts(filename)

# %%
inputPath = "Data1/"
fileList = folderWalk(inputPath)
newFileList = []
for fileName in fileList:
    # print("hi")
    xFileName = fileName.split('/')[-1]
    if xFileName == 'err.txt' or xFileName.split('.')[-1] in ['comments', 'bak'] or xFileName[:4] == 'task':
        continue
    else:
        newFileList.append(fileName)

# %%
# Define the filename for the CSV file
csv_filename = "urdu_sampled_data.csv"
newFileList = [newFileList[0]]
# Open the CSV file in write mode and create a CSV writer object
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(["Head", "Name", "Post", "Parent", "ParentRelation", "AI", "SRL", "Pred"])

    # Iterate through each file in newFileList
    for fileName in newFileList:
        print(fileName)
        d = Document(fileName)
        for tree in d.nodeList:
            csv_writer.writerow(["----- New Sentence ------"])  # Write separator for each sentence
            for chunkNode in tree.nodeList:
                temp = list(chunkNode.attributes.values())
#                 print(temp)
                key = list(chunkNode.attributes.keys())
                print(key)
                head = ""
                ai = 0
                srl = ""
                pred = ""
                for k in range(len(key)):
                    if key[k] == "head":
                        head = temp[k]

                    elif key[k] == "pbrel":
                        ai = 1
                        srl = temp[k].split(':')[-2]
                        pred = temp[k].split(':')[-1]

                pt = temp[0].split(',')
                if len(pt) > 6:
                    post = pt[6]
                    if post == " " or post == "":
                        post = 0
                else:
                    post = 0

                # Write the extracted data to the CSV file
                csv_writer.writerow([head, chunkNode.name, post, chunkNode.parent, chunkNode.parentRelation, ai, srl, pred])

print("Data saved to", csv_filename)
